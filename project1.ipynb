# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file1='GILD.csv'
file2='IHE.csv'
file3='JNJ.csv'
file4='LLY.csv'
file5='PFE.csv'
file6='SPY.csv'
file7='SYK.csv'

# %%
gild=pd.read_csv(file1)
ihe=pd.read_csv(file2)
jnj=pd.read_csv(file3)
lly=pd.read_csv(file4)
pfe=pd.read_csv(file5)
spy=pd.read_csv(file6)
syk=pd.read_csv(file7)

# %%
gild.columns=['Gild Date', 'Gild Open', 'Gild High', 'Gild Low', 'Gild Close', 'Gild Adj Close', 'Gild Volume']
ihe.columns=['IHE Date', 'IHE Open', 'IHE High', 'IHE Low', 'IHE Close', 'IHE Adj Close', 'IHE Volume']
jnj.columns=['JNJ Date', 'JNJ Open', 'JNJ High', 'JNJ Low', 'JNJ Close', 'JNJ Adj Close', 'JNJ Volume']
lly.columns=['LLY Date', 'LLY Open', 'LLY High', 'LLY Low', 'LLY Close', 'LLY Adj Close', 'LLY Volume']
pfe.columns=['PFE Date', 'PFE Open', 'PFE High', 'PFE Low', 'PFE Close', 'PFE Adj Close', 'PFE Volume']
spy.columns=['SPY Date', 'SPY Open', 'SPY High', 'SPY Low', 'SPY Close', 'SPY Adj Close', 'SPY Volume']
syk.columns=['SYK Date', 'SYK Open', 'SYK High', 'SYK Low', 'SYK Close', 'SYK Adj Close', 'SYK Volume']

# %%
spypct=spy['SPY Close']/279.29*100
gildpct=gild['Gild Close']/70.86*100
plt.plot(spypct)
plt.plot(gildpct)
plt.figure(figsize=(30,30))
spypct.corr(gildpct)
# Out:
# -0.0978303254948312

# %%
spypct=spy['SPY Close']/279.29*100
jnjpct=jnj['JNJ Close']/146.21*100
plt.plot(spypct)
plt.plot(jnjpct)
spypct.corr(jnjpct)
# Out:
# 0.12235392128892432

# %%
spypct=spy['SPY Close']/279.29*100
llypct=lly['LLY Close']/118.51*100
plt.plot(spypct)
plt.plot(llypct)
spypct.corr(llypct)
# Out:
# -0.21971471138937376

# %%
spypct=spy['SPY Close']/279.29*100
pfepct=pfe['PFE Close']/45.99*100
plt.plot(spypct)
plt.plot(pfepct)
spypct.corr(pfepct)
# Out:
# -0.49153497394243456

# %%
spypct=spy['SPY Close']/279.29*100
ihepct=ihe['IHE Close']/160.16*100
plt.plot(spypct)
plt.plot(ihepct)
spypct.corr(ihepct)
# Out:
# 0.032140102348364195

# %%
spypct=spy['SPY Close']/279.29*100
sykpct=syk['SYK Close']/173.88*100
plt.plot(spypct)
plt.plot(sykpct)
spypct.corr(sykpct)
# Out:
# 0.8541153212898205

# %%
plt.plot(jnjpct)
plt.plot(ihepct)
jnjpct.corr(ihepct)
# Out:
# 0.7779109905730759

# %%
plt.plot(pfepct)
plt.plot(ihepct)
pfepct.corr(ihepct)
# Out:
# 0.6608352047838401

# %%
plt.plot(jnjpct)
plt.plot(ihepct)
jnjpct.corr(ihepct)
# Out:
# 0.7779109905730759

# %%
plt.plot(llypct)
plt.plot(ihepct)
llypct.corr(ihepct)
# Out:
# 0.719438593293427
